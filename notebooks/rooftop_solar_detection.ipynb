# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !mkdir -p "/content/datasets"

# %%
# !unzip -q "/content/drive/My Drive/solar panel detection/dataset.zip" -d "/content/datasets"

# %%
# !ls -R /content/datasets
# Out:
# Streaming output truncated to the last 5000 lines.
# 41-986393_-74-027239_png.rf.3e290514542e28daea4cea3d99a93a09.txt
# 41-986393_-74-027239_png.rf.7812f64e56e6e06b846e8e51865e7a07.txt
# 41-987483_-74-028816_png.rf.715ca05000331ede5d2f63618aacd1f6.txt
# 41-987483_-74-028816_png.rf.94f2db9c27f22c5eef4e1f7f23b4054b.txt
# 41-987483_-74-028816_png.rf.d98e07a4be0108559152593aaf98d5f8.txt
# 42-096737_-78-443812_png.rf.35a870f4fb5f17e26eada7e99456c802.txt
# 42-096737_-78-443812_png.rf.5195c32877faa91635411fdc97c713f5.txt
# 42-096737_-78-443812_png.rf.665bf1e3c6c44cbec80f118f295b91d5.txt
# 42-097527_-78-443834_png.rf.3b61e4e3e9582c0c2459a9e212158f60.txt
# 42-097527_-78-443834_png.rf.da43a0d01f3c643f762afe813cb1125b.txt
# 42-097527_-78-443834_png.rf.dfa6711f67b41f000e620dff58ac074f.txt
# 42-098560_-78-441799_png.rf.39efd4fce985c918916758223454919d.txt
# 42-098560_-78-441799_png.rf.45abd55028da17785762d919be8f040b.txt
# 42-098560_-78-441799_png.rf.5d618fc85b1bf47e5182cd25233ab776.txt
# ...

# %%
# !ls /content/datasets/dataset/trainvalid
# !ls /content/datasets/dataset/test
# Out:
# ls: cannot access '/content/datasets/dataset/trainvalid': No such file or directory
# images	labels

# %%
# !pip install -q ultralytics
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 61.4 MB/s eta 0:00:00

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

model.train(
    data="/content/datasets/dataset/data.yaml",  # uses your Roboflow config
    epochs=30,
    imgsz=640,
    batch=16,
    project="solar_train",
    name="geo_solar_yolov8n",
)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.3.235 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from google.colab import files
files.download("/content/solar_train/geo_solar_yolov8n/weights/best.pt")
